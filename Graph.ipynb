# %% [markdown]
# <a href="https://colab.research.google.com/github/Lanznx/Data_Structure/blob/master/Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_array = pd.read_csv("/content/drive/MyDrive/資料結構/01_Insert_ArrayList.csv")
df_vector = pd.read_csv("/content/drive/MyDrive/資料結構/02_Insert_Vector.csv")
df_linked_list = pd.read_csv("/content/drive/MyDrive/資料結構/03_Insert_LinkedList.csv")

# %%
factors = []
for k in range(0, 26):
  factors.append(2**k)

# %%
fig, ax = plt.subplots()
ax.set_xscale('log', basex=2)
ax.set_yscale('log', basey=10)
# plt.xlim(2**16, 2**25)

y1 = list(df_array['time'])
x1 = list(df_array['k'])  
plt.plot(x1, y1, label="ArrayList")

y2 = list(df_vector['time'])
x2 = list(df_vector['k'])
plt.plot(x2, y2, label="Vector")

y3 = list(df_linked_list['time'])
x3 = list(df_linked_list['k'])
plt.plot(x3, y3, label="Linked List")
plt.legend()

plt.savefig('foo1.png')

# %%
fig, ax = plt.subplots()
ax.set_xscale('log', basex=2)
ax.set_yscale('log', basey=10)
plt.xlim(2**23, 2**25)

y1 = list(df_array['time'])
x1 = list(df_array['k'])  
plt.plot(x1, y1, label="ArrayList")

y2 = list(df_vector['time'])
x2 = list(df_vector['k'])
plt.plot(x2, y2, label="Vector")

y3 = list(df_linked_list['time'])
x3 = list(df_linked_list['k'])
plt.plot(x3, y3, label="Linked List")
plt.legend()

# %%
fig, ax = plt.subplots()

y1 = list(df_array['time'])
x1 = list(df_array['k'])  
plt.plot(x1, y1, label="ArrayList")

y2 = list(df_vector['time'])
x2 = list(df_vector['k'])
plt.plot(x2, y2, label="Vector")

y3 = list(df_linked_list['time'])
x3 = list(df_linked_list['k'])
plt.plot(x3, y3, label="Linked List")
plt.legend()

plt.savefig('foo1.png')
